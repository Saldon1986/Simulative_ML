# %% [markdown]
# <a href="https://colab.research.google.com/github/Saldon1986/Simulative_ML/blob/main/CRM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **3 кейс**
#
# **CRM**

# %% [markdown]
# ### **Решения**

# %% [markdown]
# #### **Задача 1**
#
# Создайте класс `Lead`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
class Lead:
  def __init__(self, lead_id: int, datetime: str, page: str, form_title: str, contacts: str, name: str):
    self.lead_id = lead_id
    self.datetime = datetime
    self.page = page
    self.form_title = form_title
    self.contacts = contacts
    self.name = name

  def to_dict(self):
    return {'lead_id': self.lead_id,
            'datetime': self.datetime,
            'page': self.page,
            'form_title': self.form_title,
            'contacts': self.contacts,
            'name': self.name}

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
lead = Lead(1, '2023-07-01 10:00', 'example.com', 'Обратная связь', 'ivan@example.com', 'Иван Иванов')
res = lead.to_dict()

try:
    assert res == {'lead_id': 1,
                   'datetime': '2023-07-01 10:00',
                   'page': 'example.com',
                   'form_title': 'Обратная связь',
                   'contacts': 'ivan@example.com',
                   'name': 'Иван Иванов'}
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 2**
#
# Создайте класс `Simulator`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
class Simulator:
  def __init__(self, simulator_type, version):
    self.simulator_type = simulator_type
    self.version = version

  def to_dict(self):
    return {'simulator_type': self.simulator_type, 'version': self.version}

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
simulator = Simulator('Type A', '1.0')
res2 = simulator.to_dict()

try:
    assert res2 == {'simulator_type': 'Type A', 'version': '1.0'}
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 3**
#
# Определите класс `SalesFunnel`. Пока без метода `process_lead`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
class SalesFunnel:
  def __init__(self, stages=[]):
    self.stages = stages

  def add_stage(self, stage):
    self.stages.append(stage)

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
funnel = SalesFunnel()
funnel.add_stage('Stage 1')
funnel.add_stage('Stage 2')
funnel.add_stage('Stage 3')
res3 = funnel.stages

try:
    assert res3 == ['Stage 1', 'Stage 2', 'Stage 3']
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 4**
#
# К классу `SalesFunnel` добавьте метод `process_lead`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
import requests

# %%
class SalesFunnel:
  def __init__(self, stages=[]):
    self.stages = stages

  def add_stage(self, stage):
    self.stages.append(stage)

  def process_lead(self, lead):
    res_messages = []
    res_messages.append(f'Обработка лида {lead.lead_id} - Текущий этап: {self.stages[0]}') #1+2

    #3 POST req
    crm_url = "https://itresume.com/crm/api/leads"
    crm_params = {
        'lead_id': lead.lead_id,
        'datetime': lead.datetime,
        'page': lead.page,
        'form_title': lead.form_title,
        'contacts': lead.contacts,
        'name': lead.name
    }
    response = requests.post(crm_url, json=crm_params)

    res_messages.append('Данные лида успешно отправлены в CRM' if response.status_code == 200 else 'Не удалось отправить данные лида в CRM')

    if len(self.stages) > 1:
      res_messages.append(f'Перемещаем лид {lead.lead_id} на следующий этап: {self.stages[1]}')
    else:
      res_messages.append(f'Лид {lead.lead_id} достиг конца воронки')
    return res_messages

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
sales_funnel = SalesFunnel(["Генерация лида", "Подтверждение", "Предложение", "Возражение"])
lead = Lead("123", "2023-07-01", "example.com", "Свяжитесь с нами", "ivan@example.com", "Иван Иванов")
res4 = sales_funnel.process_lead(lead)

try:
    assert res4 == ['Обработка лида 123 - Текущий этап: Генерация лида',
                    'Не удалось отправить данные лида в CRM',
                    'Перемещаем лид 123 на следующий этап: Подтверждение']
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!
