# %% [markdown]
# <a href="https://colab.research.google.com/github/Saldon1986/Simulative_ML/blob/main/%D0%A2%D1%80%D0%B5%D0%BA_%D0%B7%D0%B0%D0%B4%D0%B0%D1%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **2 кейс**
#
# **Трек задач**

# %% [markdown]
# ### **Решения**

# %% [markdown]
# #### **Задача 1**
#
# Для начала определите классы `Task` и `Project`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
class Task:
  def __init__(self, task_id, name, description, status, duration):
    self.__task_id = task_id
    self.__name = name
    self.__description = description
    self.__status = status
    self.__duration = duration

  def get_name(self):
    return self.__name

  def get_description(self):
    return self.__description

  def get_status(self):
    return self.__status

  def get_duration(self):
    return self.__duration

# %%
class Project:
  def __init__(self):
    self.__task_list = []

  def add_task(self, task):
    self.__task_list.append(task)
    return self.__task_list

  def remove_task(self, task_id):
    for ind, el in enumerate(self.__task_list):
      if el.task_id == task_id:
        del self.__task_list[ind]
    return self.__task_list

  def get_all_tasks(self):
    res = []
    for el in self.__task_list:
      res.append([el.get_name(), el.get_description(), el.get_status()])
    return res

  def __iter__(self):
    return iter(self.__task_list)

# %%
#@title ✏️ Проверка: чтобы проверить свое решение запустите код в этой ячейке
task1 = Task(1, "Задача 1", "Описание", "Выполняется", 14)
task2 = Task(2, "Задача 2", "Описание", "Выполняется", 8)
task3 = Task(3, "Задача 3", "Описание", "Завершена", 3)
task4 = Task(4, "Задача 4", "Описание: срочно", "Выполняется", 7)

project = Project()
project.add_task(task1)
project.add_task(task2)
project.add_task(task3)
project.add_task(task4)

res = []
for task in project:
  name = task.get_name()
  description = task.get_description()
  status = task.get_status()
  res.append((name, description, status))

try:
    assert res == [('Задача 1', 'Описание', 'Выполняется'),
                   ('Задача 2', 'Описание', 'Выполняется'),
                   ('Задача 3', 'Описание', 'Завершена'),
                   ('Задача 4', 'Описание: срочно', 'Выполняется')]
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 2**
#
# Определите класс `Analysis`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
class Analysis:
  @staticmethod
  def count_tasks(project):
    return len(project.get_all_tasks())

  @staticmethod
  def count_tasks_by_status(project, status):
    return sum([1 if el.get_status() == status else 0 for el in project.__iter__()])

  @staticmethod
  def find_longest_task(project):
    longest_task = None
    for el in project.__iter__():
      if longest_task is None or longest_task.get_duration() <= el.get_duration():
        longest_task = el
    return longest_task

# %%
#@title ✏️ Проверка: чтобы проверить свое решение запустите код в этой ячейке
res2 = Analysis.count_tasks(project)
res3 = Analysis.count_tasks_by_status(project, "Выполняется")
res4 = Analysis.find_longest_task(project).get_name()

try:
    assert res2 == 4
    assert res3 == 3
    assert res4 == 'Задача 1'
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 3**
#
# Напишите `EnhancedAnalysis`

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
class EnhancedAnalysis(Analysis):
  def find_tasks_with_keywords(project, keywords):
    res = []
    for tsk in project.__iter__():
      for keyword in keywords:
        if keyword in tsk.get_description() or keyword in tsk.get_name():
          res.append(tsk)
    return(res)

# %%
#@title ✏️ Проверка: чтобы проверить свое решение запустите код в этой ячейке
keywords = ["срочно"]
found_tasks = EnhancedAnalysis.find_tasks_with_keywords(project, keywords)
res5 = []
for task in found_tasks:
  res5.append(task.get_name())

try:
    assert res5 == ['Задача 4']
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!
